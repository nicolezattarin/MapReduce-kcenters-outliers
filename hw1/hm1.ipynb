# %%
import numpy as np
import pandas as pd
from pyspark import SparkContext, SparkConf

# %%
df = pd.read_csv('data/sample_10000.csv', sep=',', header=None)
df.columns = ['TransactionID', 'ProductID', 'Description','Quantity', 'InvoiceDate','UnitPrice', 'CustomerID', 'Country'] 
df.head()
# Out:
#    TransactionID ProductID                        Description  Quantity  \
# 0         536365    84029E     RED WOOLLY HOTTIE WHITE HEART.         6
# 1         536366     22632          HAND WARMER RED POLKA DOT         6
# 2         536367     22749  FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 3         536368     22960           JAM MAKING SET WITH JARS         6
# 4         536369     21756           BATH BUILDING BLOCK WORD         3
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       3.39       17850  United_Kingdom
# 1  2010-12-01 08:28:00       1.85       17850  United_Kingdom
# 2  2010-12-01 08:34:00       3.75       13047  United_Kingdom
# 3  2010-12-01 08:34:00       4.25       13047  United_Kingdom
# 4  2010-12-01 08:35:00       5.95       13047  United_Kingdom

# %%
u=df[df['Country']=='Italy']
u
# Out:
#       TransactionID ProductID                        Description  Quantity  \
# 880          539752     22423           REGENCY CAKESTAND 3 TIER         2
# 1295         541703      POST                            POSTAGE         2
# 1941         544399     84375      SET OF 20 KIDS COOKIE CUTTERS        12
# 2275         545664     21623       VINTAGE UNION JACK MEMOBOARD         2
# 2585         546875     21755           LOVE BUILDING BLOCK WORD         6
# 2880         547914     84375      SET OF 20 KIDS COOKIE CUTTERS        12
# 2886         547931      POST                            POSTAGE         1
# 5040         555843     22804    CANDLEHOLDER PINK HANGING HEART         6
# 5109         556119     23084                 RABBIT NIGHT LIGHT        24
# 6479         561259     22844   VINTAGE CREAM DOG FOOD CONTAINER         2
# 6776         562424     22423           REGENCY CAKESTAND 3 TIER         1
# 6811         562528     20718          RED RETROSPOT SHOPPER BAG        10
# 6920         562922     22556     PLASTERS IN TIN CIRCUS PARADE         12
# 7389         564476     22776        SWEETHEART CAKESTAND 3 TIER         1
# 8193         567478     22845   VINTAGE CREAM CAT FOOD CONTAINER         2
# 9140         570919     22847        BREAD BIN DINER STYLE IVORY         2
# 9519         572457     22273               FELTCRAFT DOLL MOLLY         6
# 9568         572695     22961             JAM MAKING SET PRINTED        12
# 9641         572934      POST                            POSTAGE         4
# 9778         573365     22720  SET OF 3 CAKE TINS PANTRY DESIGN         12
# 9829         573508     84879      ASSORTED COLOUR BIRD ORNAMENT         8
# 9854         573768      POST                            POSTAGE         3
# 9919         574022     23084                 RABBIT NIGHT LIGHT        48
#
#               InvoiceDate  UnitPrice  CustomerID Country
# 880   2010-12-21 15:43:00      12.75       12515   Italy
# 1295  2011-01-21 09:52:00      28.00       12594   Italy
# 1941  2011-02-18 12:28:00       2.10       12594   Italy
# 2275  2011-03-04 15:15:00       9.95       12584   Italy
# 2585  2011-03-17 16:38:00       5.95       12514   Italy
# 2880  2011-03-28 12:35:00       2.10       12594   Italy
# 2886  2011-03-28 14:01:00      28.00       12594   Italy
# 5040  2011-06-07 13:00:00       2.95       12584   Italy
# 5109  2011-06-09 10:05:00       1.79       12594   Italy
# 6479  2011-07-26 12:04:00       8.50       12584   Italy
# 6776  2011-08-04 17:07:00      12.75       12584   Italy
# 6811  2011-08-05 13:52:00       1.25       12610   Italy
# 6920  2011-08-10 14:26:00       1.65       12594   Italy
# 7389  2011-08-25 12:57:00       9.95       12610   Italy
# 8193  2011-09-20 13:21:00       6.35       12584   Italy
# 9140  2011-10-13 10:57:00      16.95       12584   Italy
# 9519  2011-10-24 12:44:00       2.95       12594   Italy
# 9568  2011-10-25 14:23:00       1.45       12610   Italy
# 9641  2011-10-27 10:18:00      40.00       12610   Italy
# 9778  2011-10-30 13:13:00       4.95       12584   Italy
# 9829  2011-10-31 12:11:00       1.69       12552   Italy
# 9854  2011-11-01 10:02:00      40.00       12552   Italy
# 9919  2011-11-02 12:20:00       1.79       12594   Italy

# %%
s = ['536365,84029E,RED WOOLLY HOTTIE WHITE HEART.,6,2010-12-01 08:26:00,3.39,17850,United_Kingdom',
 '536366,22632,HAND WARMER RED POLKA DOT,6,2010-12-01 08:28:00,1.85,17850,United_Kingdom', 
 '536368,22960,JAM MAKING SET WITH JARS,6,2010-12-01 08:34:00,4.25,13047,Italy', 
 '536369,37449,CERAMIC CAKE STAND + HANGING CAKES,3,2010-12-01 08:35:00,5.95,13047,United_Kingdom',
  '536372,22633,HAND WARMER UNION JACK,6,2010-12-01 09:01:00,1.85,17850,United_Kingdom', 
  '536374,21258,VICTORIAN SEWING BOX LARGE,32,2010-12-01 09:09:00,10.95,15100,United_Kingdom', 
  '536376,21733,RED HANGING HEART T-LIGHT HOLDER,64,2010-12-01 09:32:00,2.55,15291,Italy', 
  '536377,22632,HAND WARMER RED POLKA DOT,6,2010-12-01 09:34:00,1.85,17850,United_Kingdom',
   '536380,22961,JAM MAKING SET PRINTED,24,2010-12-01 09:41:00,1.45,17809,Italy', 
   '536385,22961,JAM MAKING SET PRINTED,12,2010-12-01 09:56:00,1.45,17420,Italy']

# %%
s_split = [x.split(',') for x in s]
s_split
# Out:
# [['536365',
#   '84029E',
#   'RED WOOLLY HOTTIE WHITE HEART.',
#   '6',
#   '2010-12-01 08:26:00',
#   '3.39',
#   '17850',
#   'United_Kingdom'],
#  ['536366',
#   '22632',
#   'HAND WARMER RED POLKA DOT',
#   '6',
#   '2010-12-01 08:28:00',
#   '1.85',
#   '17850',
#   'United_Kingdom'],
#  ['536368',
#   '22960',
#   'JAM MAKING SET WITH JARS',
#   '6',
#   '2010-12-01 08:34:00',
#   '4.25',
#   '13047',
#   'Italy'],
#  ['536369',
#   '37449',
#   'CERAMIC CAKE STAND + HANGING CAKES',
#   '3',
#   '2010-12-01 08:35:00',
#   '5.95',
#   '13047',
#   'United_Kingdom'],
#  ['536372',
#   '22633',
#   'HAND WARMER UNION JACK',
#   '6',
#   '2010-12-01 09:01:00',
#   '1.85',
#   '17850',
#   'United_Kingdom'],
#  ['536374',
#   '21258',
#   'VICTORIAN SEWING BOX LARGE',
#   '32',
#   '2010-12-01 09:09:00',
#   '10.95',
#   '15100',
#   'United_Kingdom'],
#  ['536376',
#   '21733',
#   'RED HANGING HEART T-LIGHT HOLDER',
#   '64',
#   '2010-12-01 09:32:00',
#   '2.55',
#   '15291',
#   'Italy'],
#  ['536377',
#   '22632',
#   'HAND WARMER RED POLKA DOT',
#   '6',
#   '2010-12-01 09:34:00',
#   '1.85',
#   '17850',
#   'United_Kingdom'],
#  ['536380',
#   '22961',
#   'JAM MAKING SET PRINTED',
#   '24',
#   '2010-12-01 09:41:00',
#   '1.45',
#   '17809',
#   'Italy'],
#  ['536385',
#   '22961',
#   'JAM MAKING SET PRINTED',
#   '12',
#   '2010-12-01 09:56:00',
#   '1.45',
#   '17420',
#   'Italy']]
